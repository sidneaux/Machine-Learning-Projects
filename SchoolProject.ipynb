# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
graduation_ = pd.read_csv("2005-2010_Graduation_Outcomes_-_School_Level.csv")
Math_test = pd.read_csv("2006_-_2011_NYS_Math_Test_Results_By_Grade_-_School_Level_-_All_Students.csv")
Class_size = pd.read_csv("2010-2011_Class_Size_-_School-level_detail.csv")
School_attendance = pd.read_csv("2010_-_2011_School_Attendance_and_Enrollment_Statistics_by_District.csv")
Ap_college_result = pd.read_csv("2010__AP__College_Board__School_Level_Results.csv")
SAT = pd.read_csv("2012_SAT_Results.csv")
DOE_high = pd.read_csv("2014_-_2015_DOE_High_School_Directory.csv")

# %%
graduation_[graduation_['Total Regents - n']=='s']['Total Regents - n'].count()
# Out:
# 8392

# %%
#Here I will be trying to unify the data using the 'DBN' Columns; where 'DBN' stands for District Borough Number
#"The class_size has a the DBN split into two columns so i'll try to concatenate"

# %%
Class_size["DBN"] = Class_size.apply(lambda x: "{0:02d}{1}".format(x["CSD"], x["SCHOOL CODE"]), axis=1)

# %%
pt = Class_size.groupby("DBN").agg(np.mean).head()

# %%
Class_size
# Out:
#        CSD BOROUGH SCHOOL CODE  \
# 0        1       M        M015
# 1        1       M        M015
# 2        1       M        M015
# 3        1       M        M015
# 4        1       M        M015
# 5        1       M        M015
# 6        1       M        M015
# 7        1       M        M015
# 8        1       M        M015
# 9        1       M        M015
# 10       1       M        M015
# 11       1       M        M015
# 12       1       M        M019
# 13       1       M        M019
# 14       1       M        M019
# 15       1       M        M019
# 16       1       M        M019
# 17       1       M        M019
# 18       1       M        M019
# 19       1       M        M019
# 20       1       M        M019
# 21       1       M        M019
# 22       1       M        M019
# 23       1       M        M019
# 24       1       M        M019
# 25       1       M        M020
# 26       1       M        M020
# 27       1       M        M020
# 28       1       M        M020
# ...

# %%
testr = pd.DataFrame(np.random.rand(2,8).reshape(4,4)*100, index = 'W X Y Z'.split(), columns= 'A B C D'.split())

# %%
testr['A']['X'] = 56

# %%
fling = {'a': [3,5,np.nan,6], 'b': [2,np.nan,8,6],'c': [np.nan, 4, 6, 4],'d': [3,5,np.nan,6]}

# %%
fling = pd.DataFrame(fling, index='W X Y Z'.split())

# %%
wen = fling.sort_values(by=['c'], ascending=False)
wen['new'] = 'Female Male Male Female'.split()

# %%
wen.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
wen
# Out:
#      a    b    c    d     new
# Y  NaN  8.0  6.0  NaN  Female
# X  5.0  NaN  4.0  5.0    Male
# Z  6.0  6.0  4.0  6.0    Male
# W  3.0  2.0  NaN  3.0  Female

# %%
sns.barplot(x='a',y='new', data=wen)
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
car_set = pd.read_excel('CAR Dataset Accuracy Checker.xlsx')

# %%
car_set.head()
# Out:
#       States  Values  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0       Abia    91.5         NaN         NaN         NaN         NaN
# 1    Adamawa    37.3         NaN         NaN         NaN         NaN
# 2  Akwa Ibom    39.7         NaN         NaN         NaN         NaN
# 3    Anambra    91.5         NaN         NaN         NaN         NaN
# 4     Bauchi     7.9         NaN         NaN         NaN         NaN
#
#    Unnamed: 6      a  Unnamed: 8    b  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN  200.0         NaN  200          NaN          NaN          NaN
# 1         NaN  400.0         NaN  202          NaN          NaN          NaN
# 2         NaN    0.0         NaN  206          NaN          NaN          NaN
# 3         NaN  201.0         NaN  207          NaN          NaN          NaN
# 4         NaN  206.0         NaN  192          NaN          NaN          NaN
#
#       Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16     Unnamed: 17  \
# ...

# %%
h = car_set.sort_values('Values', ascending=False)

# %%
sns.set(style='darkgrid', rc={'figure.figsize':(9,12)})
sns.set_context("talk")
s sns.barplot(x='Values', y='States', data=h, palette="Blues_d", capsize=.6)
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
newn = {'a':['yes', 'no', 'yes','yes','no','yes','no'], 'b':[3,4,5,6,3,5,7]}

# %%
newn = pd.DataFrame(newn)

# %%
newn
# Out:
#      a  b
# 0  yes  3
# 1   no  4
# 2  yes  5
# 3  yes  6
# 4   no  3
# 5  yes  5
# 6   no  7

# %%
def changr(col):
    a = col
    if a == 'yes':
        return 1
    else:
        return 0

# %%
newn['trial']=newn['a'].apply(changr)

# %%
newn.to_csv('anothercsvsave.csv')
